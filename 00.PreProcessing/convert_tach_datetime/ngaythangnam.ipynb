# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df= pd.read_csv('thangngaynam.csv')
df
# Out:
#       index             Name     Time    Store  \
# 0     46885        Stephanie  1/13/19  Walmart
# 1     43723     Frank GÃ³mez  1/13/21  Walmart
# 2     43724       Kyle Brady  1/13/21  Walmart
# 3     43725     Beth Elliott  1/13/21  Walmart
# 4     43726  Marion Anderson  1/13/21  Walmart
# ...     ...              ...      ...      ...
# 4652  42264       Nicole Gee  9/30/21  Walmart
# 4653  42265     Elaine kelly  9/30/21  Walmart
# 4654  42266     Bryce Koontz  9/30/21  Walmart
# 4655  42267          CDurham  9/30/21  Walmart
# 4656  42268        John John  9/30/21  Walmart
#
#                                                 Comment
# 0     Never can keep store stocked !!!! Out of thing...
# 1     Horrible place staff are rude and would not re...
# 2     Ordered 18 frames got my delivery today opened...
# 3     Walmart you just lost about 75 million custome...
# 4     Walmart is enjoying a huge increase in online ...
# ...                                                 ...
# ...

# %%
df.dtypes
# Out:
# index       int64
# Name       object
# Time       object
# Store      object
# Comment    object
# dtype: object

# %%
#delete NaN values
df.dropna(inplace=True)
df = df.reset_index()
df
# Out:
#       level_0  index             Name     Time    Store  \
# 0           0  46885        Stephanie  1/13/19  Walmart
# 1           1  43723     Frank GÃ³mez  1/13/21  Walmart
# 2           2  43724       Kyle Brady  1/13/21  Walmart
# 3           3  43725     Beth Elliott  1/13/21  Walmart
# 4           4  43726  Marion Anderson  1/13/21  Walmart
# ...       ...    ...              ...      ...      ...
# 4652     4652  42264       Nicole Gee  9/30/21  Walmart
# 4653     4653  42265     Elaine kelly  9/30/21  Walmart
# 4654     4654  42266     Bryce Koontz  9/30/21  Walmart
# 4655     4655  42267          CDurham  9/30/21  Walmart
# 4656     4656  42268        John John  9/30/21  Walmart
#
#                                                 Comment
# 0     Never can keep store stocked !!!! Out of thing...
# 1     Horrible place staff are rude and would not re...
# 2     Ordered 18 frames got my delivery today opened...
# 3     Walmart you just lost about 75 million custome...
# ...

# %%
# keep number and remove character and alphabet in Time column
df['Time'] = df['Time'].str.replace('[a-zA-Z]', '')
df
# Out:
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_1648\1946158695.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Time'] = df['Time'].str.replace('[a-zA-Z]', '')
#       level_0  index             Name     Time    Store  \
# 0           0  46885        Stephanie  1/13/19  Walmart
# 1           1  43723     Frank GÃ³mez  1/13/21  Walmart
# 2           2  43724       Kyle Brady  1/13/21  Walmart
# 3           3  43725     Beth Elliott  1/13/21  Walmart
# 4           4  43726  Marion Anderson  1/13/21  Walmart
# ...       ...    ...              ...      ...      ...
# 4652     4652  42264       Nicole Gee  9/30/21  Walmart
# 4653     4653  42265     Elaine kelly  9/30/21  Walmart
# 4654     4654  42266     Bryce Koontz  9/30/21  Walmart
# 4655     4655  42267          CDurham  9/30/21  Walmart
# 4656     4656  42268        John John  9/30/21  Walmart
#
#                                                 Comment
# ...

# %%
#insert 0 in first if Time column len = 9
df['Time'] = df['Time'].apply(lambda x: '0' + x if len(x) == 9 else x)
df
# Out:
#       level_0  index             Name     Time    Store  \
# 0           0  46885        Stephanie  1/13/19  Walmart
# 1           1  43723     Frank GÃ³mez  1/13/21  Walmart
# 2           2  43724       Kyle Brady  1/13/21  Walmart
# 3           3  43725     Beth Elliott  1/13/21  Walmart
# 4           4  43726  Marion Anderson  1/13/21  Walmart
# ...       ...    ...              ...      ...      ...
# 4652     4652  42264       Nicole Gee  9/30/21  Walmart
# 4653     4653  42265     Elaine kelly  9/30/21  Walmart
# 4654     4654  42266     Bryce Koontz  9/30/21  Walmart
# 4655     4655  42267          CDurham  9/30/21  Walmart
# 4656     4656  42268        John John  9/30/21  Walmart
#
#                                                 Comment
# 0     Never can keep store stocked !!!! Out of thing...
# 1     Horrible place staff are rude and would not re...
# 2     Ordered 18 frames got my delivery today opened...
# 3     Walmart you just lost about 75 million custome...
# ...

# %%
#insert 0 in first if Time column len = 9
df['Time'] = df['Time'].apply(lambda x: '0' + x if len(x) == 7 else x)
df
# Out:
#       level_0  index             Name      Time    Store  \
# 0           0  46885        Stephanie  01/13/19  Walmart
# 1           1  43723     Frank GÃ³mez  01/13/21  Walmart
# 2           2  43724       Kyle Brady  01/13/21  Walmart
# 3           3  43725     Beth Elliott  01/13/21  Walmart
# 4           4  43726  Marion Anderson  01/13/21  Walmart
# ...       ...    ...              ...       ...      ...
# 4652     4652  42264       Nicole Gee  09/30/21  Walmart
# 4653     4653  42265     Elaine kelly  09/30/21  Walmart
# 4654     4654  42266     Bryce Koontz  09/30/21  Walmart
# 4655     4655  42267          CDurham  09/30/21  Walmart
# 4656     4656  42268        John John  09/30/21  Walmart
#
#                                                 Comment
# 0     Never can keep store stocked !!!! Out of thing...
# 1     Horrible place staff are rude and would not re...
# 2     Ordered 18 frames got my delivery today opened...
# ...

# %%
#change if the end 22 to 2022 and 21 to 2021 and 20 to 2020 in Time column
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2022' if x[-3:] == '/22' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2021' if x[-3:] == '/21' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2020' if x[-3:] == '/20' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2019' if x[-3:] == '/19' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2018' if x[-3:] == '/18' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2017' if x[-3:] == '/17' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2016' if x[-3:] == '/16' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2015' if x[-3:] == '/15' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2014' if x[-3:] == '/14' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2013' if x[-3:] == '/13' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2012' if x[-3:] == '/12' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2011' if x[-3:] == '/11' else x)
df['Time'] = df['Time'].apply(lambda x: x[:-3] + '/2010' if x[-3:] == '/10' else x)

df
# Out:
#       level_0  index             Name        Time    Store  \
# 0           0  46885        Stephanie  01/13/2019  Walmart
# 1           1  43723     Frank GÃ³mez  01/13/2021  Walmart
# 2           2  43724       Kyle Brady  01/13/2021  Walmart
# 3           3  43725     Beth Elliott  01/13/2021  Walmart
# 4           4  43726  Marion Anderson  01/13/2021  Walmart
# ...       ...    ...              ...         ...      ...
# 4652     4652  42264       Nicole Gee  09/30/2021  Walmart
# 4653     4653  42265     Elaine kelly  09/30/2021  Walmart
# 4654     4654  42266     Bryce Koontz  09/30/2021  Walmart
# 4655     4655  42267          CDurham  09/30/2021  Walmart
# 4656     4656  42268        John John  09/30/2021  Walmart
#
#                                                 Comment
# 0     Never can keep store stocked !!!! Out of thing...
# 1     Horrible place staff are rude and would not re...
# 2     Ordered 18 frames got my delivery today opened...
# ...

# %%
#from string format 08 16 2008 to datetimw type 16/08/2008
df['Time'] = pd.to_datetime(df['Time'], format='%m/%d/%Y')

# %%
#change  2022-09-22 to 22/09/2022
df['Time'] = df['Time'].dt.strftime('%d/%m/%Y')
df
# Out:
#       level_0  index             Name        Time    Store  \
# 0           0  46885        Stephanie  13/01/2019  Walmart
# 1           1  43723     Frank GÃ³mez  13/01/2021  Walmart
# 2           2  43724       Kyle Brady  13/01/2021  Walmart
# 3           3  43725     Beth Elliott  13/01/2021  Walmart
# 4           4  43726  Marion Anderson  13/01/2021  Walmart
# ...       ...    ...              ...         ...      ...
# 4652     4652  42264       Nicole Gee  30/09/2021  Walmart
# 4653     4653  42265     Elaine kelly  30/09/2021  Walmart
# 4654     4654  42266     Bryce Koontz  30/09/2021  Walmart
# 4655     4655  42267          CDurham  30/09/2021  Walmart
# 4656     4656  42268        John John  30/09/2021  Walmart
#
#                                                 Comment
# 0     Never can keep store stocked !!!! Out of thing...
# 1     Horrible place staff are rude and would not re...
# 2     Ordered 18 frames got my delivery today opened...
# ...

# %%
#to csv file
df.to_csv('thangngaynamx.csv', index=False)
