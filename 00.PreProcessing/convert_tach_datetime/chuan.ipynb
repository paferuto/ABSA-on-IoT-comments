# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df= pd.read_csv('chuan.csv')
df
# Out:
#        Unnamed: 0             Name        Time    Store  \
# 0           34400      macantonioc  25/06/2007  DigInfo
# 1           34399      donkeyfly69  27/02/2008  DigInfo
# 2           34398  upanddownlevel9  13/02/2009  DigInfo
# 3           34397   Serenity'sEdge  19/10/2009  DigInfo
# 4           34396   jordandaperson  06/11/2009  DigInfo
# ...           ...              ...         ...      ...
# 69684       40115            Cocoa  09/12/2022  Walmart
# 69685       40116           georay  09/12/2022  Walmart
# 69686       40119    Sankar Achary  09/12/2022  Walmart
# 69687       40135            Cocoa  09/12/2022  Walmart
# 69688       40156            Am AW  09/12/2022  Walmart
#
#                                                  Comment
# 0                                            Interesting
# 1      it doesn&#39;t even seem more convenient...\r\...
# 2      hmm why dont we just use our brains while we s...
# 3      The more electronic we become, the more power ...
# 4      its a product aimed at customer loyalty and co...
# ...                                                  ...
# 69684  Placed my order on Saturday. Got two items tod...
# 69685  I'm a long time Walmart customer. but i went t...
# 69686  Walmart online delivery is bogus in Montreal C...
# 69687  Placed my order on Saturday. Got two items tod...
# 69688  Horrible customer service. I purchased a baby ...
#
# [69689 rows x 5 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# Name          object
# Time          object
# Store         object
# Comment       object
# dtype: object

# %%
# change time column to string type
df['Time'] = df['Time'].astype(str)
#from string format Aug. 16, 2008 to 16/08/2008
# change Sep. 16, 2008 to 16/09/2008, Aug. 16, 2008 to 16/08/2008, etc in Time column
df['Time'] = df['Time'].str.replace('January', '01')
df['Time'] = df['Time'].str.replace('February', '02')
df['Time'] = df['Time'].str.replace('March', '03')
df['Time'] = df['Time'].str.replace('April', '04')
df['Time'] = df['Time'].str.replace('May', '05')
df['Time'] = df['Time'].str.replace('June', '06')
df['Time'] = df['Time'].str.replace('July', '07')
df['Time'] = df['Time'].str.replace('August', '08')
df['Time'] = df['Time'].str.replace('September', '09')
df['Time'] = df['Time'].str.replace('October', '10')
df['Time'] = df['Time'].str.replace('November', '11')
df['Time'] = df['Time'].str.replace('December', '12')
df
# Out:
#        Unnamed: 0             Name        Time    Store  \
# 0           34400      macantonioc  25/06/2007  DigInfo
# 1           34399      donkeyfly69  27/02/2008  DigInfo
# 2           34398  upanddownlevel9  13/02/2009  DigInfo
# 3           34397   Serenity'sEdge  19/10/2009  DigInfo
# 4           34396   jordandaperson  06/11/2009  DigInfo
# ...           ...              ...         ...      ...
# 69684       40115            Cocoa  09/12/2022  Walmart
# 69685       40116           georay  09/12/2022  Walmart
# 69686       40119    Sankar Achary  09/12/2022  Walmart
# 69687       40135            Cocoa  09/12/2022  Walmart
# 69688       40156            Am AW  09/12/2022  Walmart
#
#                                                  Comment
# 0                                            Interesting
# 1      it doesn&#39;t even seem more convenient...\r\...
# 2      hmm why dont we just use our brains while we s...
# 3      The more electronic we become, the more power ...
# 4      its a product aimed at customer loyalty and co...
# ...                                                  ...
# 69684  Placed my order on Saturday. Got two items tod...
# 69685  I'm a long time Walmart customer. but i went t...
# 69686  Walmart online delivery is bogus in Montreal C...
# 69687  Placed my order on Saturday. Got two items tod...
# 69688  Horrible customer service. I purchased a baby ...
#
# [69689 rows x 5 columns]

# %%
# keep number and remove character and alphabet in Time column
df['Time'] = df['Time'].str.replace('[a-zA-Z]', '')
df
# Out:
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\1946158695.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Time'] = df['Time'].str.replace('[a-zA-Z]', '')
#        Unnamed: 0             Name        Time    Store  \
# 0           34400      macantonioc  25/06/2007  DigInfo
# 1           34399      donkeyfly69  27/02/2008  DigInfo
# 2           34398  upanddownlevel9  13/02/2009  DigInfo
# 3           34397   Serenity'sEdge  19/10/2009  DigInfo
# 4           34396   jordandaperson  06/11/2009  DigInfo
# ...           ...              ...         ...      ...
# 69684       40115            Cocoa  09/12/2022  Walmart
# 69685       40116           georay  09/12/2022  Walmart
# 69686       40119    Sankar Achary  09/12/2022  Walmart
# 69687       40135            Cocoa  09/12/2022  Walmart
# 69688       40156            Am AW  09/12/2022  Walmart
#
#                                                  Comment
# 0                                            Interesting
# 1      it doesn&#39;t even seem more convenient...\r\...
# 2      hmm why dont we just use our brains while we s...
# 3      The more electronic we become, the more power ...
# 4      its a product aimed at customer loyalty and co...
# ...                                                  ...
# 69684  Placed my order on Saturday. Got two items tod...
# 69685  I'm a long time Walmart customer. but i went t...
# 69686  Walmart online delivery is bogus in Montreal C...
# 69687  Placed my order on Saturday. Got two items tod...
# 69688  Horrible customer service. I purchased a baby ...
#
# [69689 rows x 5 columns]

# %%
# 09 9 2022 to 09 09 2022 in Time column if len month is 1 digit and len day is 1 digit
df['Time'] = df['Time'].str.replace(' 9, ', ' 09 ')
df['Time'] = df['Time'].str.replace(' 8, ', ' 08 ')
df['Time'] = df['Time'].str.replace(' 7, ', ' 07 ')
df['Time'] = df['Time'].str.replace(' 6, ', ' 06 ')
df['Time'] = df['Time'].str.replace(' 5, ', ' 05 ')
df['Time'] = df['Time'].str.replace(' 4, ', ' 04 ')
df['Time'] = df['Time'].str.replace(' 3, ', ' 03 ')
df['Time'] = df['Time'].str.replace(' 2, ', ' 02 ')
df['Time'] = df['Time'].str.replace(' 1, ', ' 01 ')
df
# Out:
#        Unnamed: 0             Name        Time    Store  \
# 0           34400      macantonioc  25/06/2007  DigInfo
# 1           34399      donkeyfly69  27/02/2008  DigInfo
# 2           34398  upanddownlevel9  13/02/2009  DigInfo
# 3           34397   Serenity'sEdge  19/10/2009  DigInfo
# 4           34396   jordandaperson  06/11/2009  DigInfo
# ...           ...              ...         ...      ...
# 69684       40115            Cocoa  09/12/2022  Walmart
# 69685       40116           georay  09/12/2022  Walmart
# 69686       40119    Sankar Achary  09/12/2022  Walmart
# 69687       40135            Cocoa  09/12/2022  Walmart
# 69688       40156            Am AW  09/12/2022  Walmart
#
#                                                  Comment
# 0                                            Interesting
# 1      it doesn&#39;t even seem more convenient...\r\...
# 2      hmm why dont we just use our brains while we s...
# 3      The more electronic we become, the more power ...
# 4      its a product aimed at customer loyalty and co...
# ...                                                  ...
# 69684  Placed my order on Saturday. Got two items tod...
# 69685  I'm a long time Walmart customer. but i went t...
# 69686  Walmart online delivery is bogus in Montreal C...
# 69687  Placed my order on Saturday. Got two items tod...
# 69688  Horrible customer service. I purchased a baby ...
#
# [69689 rows x 5 columns]

# %%
#remove , . space in Time column
df['Time'] = df['Time'].str.replace(',', '')
df['Time'] = df['Time'].str.replace('.', '')
#remove !@#$%^& punctuation in Time column
df['Time'] = df['Time'].str.replace('!', '')
df['Time'] = df['Time'].str.replace('@', '')
df['Time'] = df['Time'].str.replace('#', '')
df['Time'] = df['Time'].str.replace('$', '')
df['Time'] = df['Time'].str.replace('%', '')
df['Time'] = df['Time'].str.replace('^', '')
df['Time'] = df['Time'].str.replace('&', '')
df['Time'] = df['Time'].str.replace('*', '')
df['Time'] = df['Time'].str.replace('(', '')
df['Time'] = df['Time'].str.replace(')', '')
df['Time'] = df['Time'].str.replace('-', '')
df['Time'] = df['Time'].str.replace('_', '')
df['Time'] = df['Time'].str.replace('+', '')
df['Time'] = df['Time'].str.replace('=', '')
df['Time'] = df['Time'].str.replace('{', '')
df['Time'] = df['Time'].str.replace('}', '')
df['Time'] = df['Time'].str.replace('[', '')
df['Time'] = df['Time'].str.replace(']', '')
df['Time'] = df['Time'].str.replace('|', '')
df['Time'] = df['Time'].str.replace(':', '')
df['Time'] = df['Time'].str.replace(';', '')
df['Time'] = df['Time'].str.replace('"', '')
df['Time'] = df['Time'].str.replace("'", '')
df['Time'] = df['Time'].str.replace('<', '')
df['Time'] = df['Time'].str.replace('>', '')
df['Time'] = df['Time'].str.replace('?', '')
df['Time'] = df['Time'].str.replace('/', '')
df['Time'] = df['Time'].str.replace(' ', '')
df
# Out:
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace('.', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace('$', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace('^', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace('*', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace('(', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace(')', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace('+', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace('{', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:20: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace('}', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:21: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace('[', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace(']', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace('|', '')
# C:\Users\HienPhuong\AppData\Local\Temp\ipykernel_4688\2626648843.py:30: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Time'] = df['Time'].str.replace('?', '')
#        Unnamed: 0             Name      Time    Store  \
# 0           34400      macantonioc  25062007  DigInfo
# 1           34399      donkeyfly69  27022008  DigInfo
# 2           34398  upanddownlevel9  13022009  DigInfo
# 3           34397   Serenity'sEdge  19102009  DigInfo
# 4           34396   jordandaperson  06112009  DigInfo
# ...           ...              ...       ...      ...
# 69684       40115            Cocoa  09122022  Walmart
# 69685       40116           georay  09122022  Walmart
# 69686       40119    Sankar Achary  09122022  Walmart
# 69687       40135            Cocoa  09122022  Walmart
# 69688       40156            Am AW  09122022  Walmart
#
#                                                  Comment
# 0                                            Interesting
# 1      it doesn&#39;t even seem more convenient...\r\...
# 2      hmm why dont we just use our brains while we s...
# 3      The more electronic we become, the more power ...
# 4      its a product aimed at customer loyalty and co...
# ...                                                  ...
# 69684  Placed my order on Saturday. Got two items tod...
# 69685  I'm a long time Walmart customer. but i went t...
# 69686  Walmart online delivery is bogus in Montreal C...
# 69687  Placed my order on Saturday. Got two items tod...
# 69688  Horrible customer service. I purchased a baby ...
#
# [69689 rows x 5 columns]

# %%
# remove space in Time column
df['Time'] = df['Time'].str.replace(' ', '')
#insert / in Time column at i =1 and i =3 
df['Time'] = df['Time'].str[:2] + '/' + df['Time'].str[2:4] + '/' + df['Time'].str[4:]
df
# Out:
#        Unnamed: 0             Name        Time    Store  \
# 0           34400      macantonioc  25/06/2007  DigInfo
# 1           34399      donkeyfly69  27/02/2008  DigInfo
# 2           34398  upanddownlevel9  13/02/2009  DigInfo
# 3           34397   Serenity'sEdge  19/10/2009  DigInfo
# 4           34396   jordandaperson  06/11/2009  DigInfo
# ...           ...              ...         ...      ...
# 69684       40115            Cocoa  09/12/2022  Walmart
# 69685       40116           georay  09/12/2022  Walmart
# 69686       40119    Sankar Achary  09/12/2022  Walmart
# 69687       40135            Cocoa  09/12/2022  Walmart
# 69688       40156            Am AW  09/12/2022  Walmart
#
#                                                  Comment
# 0                                            Interesting
# 1      it doesn&#39;t even seem more convenient...\r\...
# 2      hmm why dont we just use our brains while we s...
# 3      The more electronic we become, the more power ...
# 4      its a product aimed at customer loyalty and co...
# ...                                                  ...
# 69684  Placed my order on Saturday. Got two items tod...
# 69685  I'm a long time Walmart customer. but i went t...
# 69686  Walmart online delivery is bogus in Montreal C...
# 69687  Placed my order on Saturday. Got two items tod...
# 69688  Horrible customer service. I purchased a baby ...
#
# [69689 rows x 5 columns]

# %%
#from string format 08 16 2008 to datetimw type 16/08/2008
df['Time'] = pd.to_datetime(df['Time'], format='%d/%m/%Y')

# %%
#change  2022-09-22 to 22/09/2022
df['Time'] = df['Time'].dt.strftime('%d/%m/%Y')
df
# Out:
#        Unnamed: 0             Name        Time    Store  \
# 0           34400      macantonioc  25/06/2007  DigInfo
# 1           34399      donkeyfly69  27/02/2008  DigInfo
# 2           34398  upanddownlevel9  13/02/2009  DigInfo
# 3           34397   Serenity'sEdge  19/10/2009  DigInfo
# 4           34396   jordandaperson  06/11/2009  DigInfo
# ...           ...              ...         ...      ...
# 69684       40115            Cocoa  09/12/2022  Walmart
# 69685       40116           georay  09/12/2022  Walmart
# 69686       40119    Sankar Achary  09/12/2022  Walmart
# 69687       40135            Cocoa  09/12/2022  Walmart
# 69688       40156            Am AW  09/12/2022  Walmart
#
#                                                  Comment
# 0                                            Interesting
# 1      it doesn&#39;t even seem more convenient...\r\...
# 2      hmm why dont we just use our brains while we s...
# 3      The more electronic we become, the more power ...
# 4      its a product aimed at customer loyalty and co...
# ...                                                  ...
# 69684  Placed my order on Saturday. Got two items tod...
# 69685  I'm a long time Walmart customer. but i went t...
# 69686  Walmart online delivery is bogus in Montreal C...
# 69687  Placed my order on Saturday. Got two items tod...
# 69688  Horrible customer service. I purchased a baby ...
#
# [69689 rows x 5 columns]

# %%
#to csv file
df.to_csv('chuanx.csv', index=False)
