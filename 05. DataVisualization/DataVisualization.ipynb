# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Load the data
df = pd.read_csv('DataWithLabel.csv')
df
# Out:
#         Unnamed: 0         Name        Time    Store  \
# 0                0  macantonioc  25-06-2007  DigInfo
# 1                1  donkeyfly69  27-02-2008  DigInfo
# 2                2  donkeyfly69  27-02-2008  DigInfo
# 3                3  donkeyfly69  27-02-2008  DigInfo
# 4                4  donkeyfly69  27-02-2008  DigInfo
# ...            ...          ...         ...      ...
# 209573      223255      Mark H.  09-09-2020  Walmart
# 209574      223256      Mark H.  09-09-2020  Walmart
# 209575      223257     Lorna B.  09-09-2021  Walmart
# 209576      223258     Lorna B.  09-09-2021  Walmart
# 209577      223259   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3                invade privacy way much just get grocery
# 4                                           not even deep
# ...                                                   ...
# 209573     call refund tell would take day get money back
# 209574                                            walmart
# 209575                          improve site much improve
# 209576  far too many grocery available store not avail...
# 209577  place need walmart lead sell good merchandise ...
#
#                                                     label  sentiment_score  \
# 0                             ['', 'shopping experience']           0.4019
# 1                             ['', 'shopping experience']           0.0000
# 2       ['', 'technology', 'general', 'payment and che...           0.0191
# 3                                         ['', 'general']           0.0000
# 4                                                    ['']           0.0000
# ...                                                   ...              ...
# 209573    ['', 'price and value', 'payment and checkout']           0.0000
# 209574                                               ['']           0.0000
# 209575                                               ['']           0.7003
# 209576                      ['', 'technology', 'general']           0.0000
# 209577                        ['', 'shopping experience']           0.7506
#
#         polarity
# 0       positive
# 1        neutral
# 2        neutral
# 3        neutral
# 4        neutral
# ...          ...
# 209573   neutral
# 209574   neutral
# 209575  positive
# 209576   neutral
# 209577  positive
#
# [209578 rows x 8 columns]

# %%
#drop the column which year is 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017
df=df.drop(df[df['Time'].str[-4:]=='2007'].index)
df=df.drop(df[df['Time'].str[-4:]=='2008'].index)
df=df.drop(df[df['Time'].str[-4:]=='2009'].index)
df=df.drop(df[df['Time'].str[-4:]=='2010'].index)
df=df.drop(df[df['Time'].str[-4:]=='2011'].index)
df=df.drop(df[df['Time'].str[-4:]=='2012'].index)
df=df.drop(df[df['Time'].str[-4:]=='2013'].index)
df=df.drop(df[df['Time'].str[-4:]=='2014'].index)
df=df.drop(df[df['Time'].str[-4:]=='2015'].index)
df=df.drop(df[df['Time'].str[-4:]=='2016'].index)
df=df.drop(df[df['Time'].str[-4:]=='2017'].index)
df
# Out:
#         Unnamed: 0        Name        Time      Store  \
# 569            587    Jenae K.  01-06-2018  Amazon Go
# 570            588    Jenae K.  01-06-2018  Amazon Go
# 571            589    Jenae K.  01-06-2018  Amazon Go
# 572            590    Jenae K.  01-06-2018  Amazon Go
# 573            591    Jenae K.  01-06-2018  Amazon Go
# ...            ...         ...         ...        ...
# 209573      223255     Mark H.  09-09-2020    Walmart
# 209574      223256     Mark H.  09-09-2020    Walmart
# 209575      223257    Lorna B.  09-09-2021    Walmart
# 209576      223258    Lorna B.  09-09-2021    Walmart
# 209577      223259  NATISHA J.  09-09-2021    Walmart
#
#                                                   Comment  \
# 569     store awesome super cool concept definitley se...
# 570     scan app enter store grab whatever want shelf ...
# 571                   product shelf sensor know grab item
# 572                              crazy no cashier no line
# 573     super simple course still worker ensure entran...
# ...                                                   ...
# 209573     call refund tell would take day get money back
# 209574                                            walmart
# 209575                          improve site much improve
# 209576  far too many grocery available store not avail...
# 209577  place need walmart lead sell good merchandise ...
#
#                                                     label  sentiment_score  \
# 569     ['', 'data integration', 'marketing and commun...           0.9136
# 570            ['', 'technology', 'payment and checkout']           0.0772
# 571                                    ['', 'technology']           0.0000
# 572                          ['', 'payment and checkout']          -0.7003
# 573     ['', 'technology', 'shopping experience', 'pay...           0.7579
# ...                                                   ...              ...
# 209573    ['', 'price and value', 'payment and checkout']           0.0000
# 209574                                               ['']           0.0000
# 209575                                               ['']           0.7003
# 209576                      ['', 'technology', 'general']           0.0000
# 209577                        ['', 'shopping experience']           0.7506
#
#         polarity
# 569     positive
# 570     positive
# 571      neutral
# 572     negative
# 573     positive
# ...          ...
# 209573   neutral
# 209574   neutral
# 209575  positive
# 209576   neutral
# 209577  positive
#
# [159115 rows x 8 columns]

# %%
#Wordcloud positive comments
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                            background_color='white',
                            stopwords=stopwords,
                            max_words=200,
                            max_font_size=40,
                            random_state=42
                            ).generate(str(df['Comment'][df['polarity']==1]))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Comment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [7], line 12
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 stopwords = set(STOPWORDS)
#       6 wordcloud = WordCloud(
#       7                             background_color='white',
#       8                             stopwords=stopwords,
#       9                             max_words=200,
#      10                             max_font_size=40,
#      11                             random_state=42
# ---> 12                             ).generate(str(df['Comment'][df['polarity']==1]))
#      13 print(wordcloud)
#      14 fig = plt.figure(1)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Comment'

# %%
#create wordcloud for positive and negative
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from PIL import Image
import urllib
import requests

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(df['Comment'][df['polarity']=='positive'].str.cat(sep=' '))
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Comment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [6], line 11
#       8 import requests
#      10 # Create and generate a word cloud image:
# ---> 11 wordcloud = WordCloud().generate(df['Comment'][df['polarity']=='positive'].str.cat(sep=' '))
#      12 # Display the generated image:
#      13 plt.imshow(wordcloud, interpolation='bilinear')
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Comment'

# %%
#count the comment of each year
#count number of records per year
df= df['Time'].groupby(df['Time'].str[-4:]).count()
df
# Out:
# Time
# 2018    48950
# 2019    20376
# 2020    26179
# 2021    36670
# 2022    26940
# Name: Time, dtype: int64
