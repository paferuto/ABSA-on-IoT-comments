# %%
import pandas as pd

# %%
df = pd.read_csv('DataWithLabel.csv')

# %%
df
# Out:
#         Unnamed: 0         Name        Time    Store  \
# 0                0  macantonioc  25-06-2007  DigInfo
# 1                1  donkeyfly69  27-02-2008  DigInfo
# 2                2  donkeyfly69  27-02-2008  DigInfo
# 3                3  donkeyfly69  27-02-2008  DigInfo
# 4                4  donkeyfly69  27-02-2008  DigInfo
# ...            ...          ...         ...      ...
# 209573      223255      Mark H.  09-09-2020  Walmart
# 209574      223256      Mark H.  09-09-2020  Walmart
# 209575      223257     Lorna B.  09-09-2021  Walmart
# 209576      223258     Lorna B.  09-09-2021  Walmart
# 209577      223259   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3                invade privacy way much just get grocery
# ...

# %%
#drop unnecessary columns
df = df.drop(['Unnamed: 0','sentiment_score'], axis=1)
df
# Out:
#                Name        Time    Store  \
# 0       macantonioc  25-06-2007  DigInfo
# 1       donkeyfly69  27-02-2008  DigInfo
# 2       donkeyfly69  27-02-2008  DigInfo
# 3       donkeyfly69  27-02-2008  DigInfo
# 4       donkeyfly69  27-02-2008  DigInfo
# ...             ...         ...      ...
# 209573      Mark H.  09-09-2020  Walmart
# 209574      Mark H.  09-09-2020  Walmart
# 209575     Lorna B.  09-09-2021  Walmart
# 209576     Lorna B.  09-09-2021  Walmart
# 209577   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3                invade privacy way much just get grocery
# 4                                           not even deep
# ...                                                   ...
# ...

# %%
#rename label as Aspect
df = df.rename(columns={'label':'Aspect'})

# %%
df
# Out:
#                Name        Time    Store  \
# 0       macantonioc  25-06-2007  DigInfo
# 1       donkeyfly69  27-02-2008  DigInfo
# 2       donkeyfly69  27-02-2008  DigInfo
# 3       donkeyfly69  27-02-2008  DigInfo
# 4       donkeyfly69  27-02-2008  DigInfo
# ...             ...         ...      ...
# 209573      Mark H.  09-09-2020  Walmart
# 209574      Mark H.  09-09-2020  Walmart
# 209575     Lorna B.  09-09-2021  Walmart
# 209576     Lorna B.  09-09-2021  Walmart
# 209577   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3                invade privacy way much just get grocery
# 4                                           not even deep
# ...                                                   ...
# ...

# %%
# convert aspect in each row to list
# remove [ and ] from aspect
df['Aspect'] = df['Aspect'].apply(lambda x: x.replace('[','').replace(']',''))
df['Aspect'] = df['Aspect'].apply(lambda x: x.split(','))
df
# Out:
#                Name        Time    Store  \
# 0       macantonioc  25-06-2007  DigInfo
# 1       donkeyfly69  27-02-2008  DigInfo
# 2       donkeyfly69  27-02-2008  DigInfo
# 3       donkeyfly69  27-02-2008  DigInfo
# 4       donkeyfly69  27-02-2008  DigInfo
# ...             ...         ...      ...
# 209573      Mark H.  09-09-2020  Walmart
# 209574      Mark H.  09-09-2020  Walmart
# 209575     Lorna B.  09-09-2021  Walmart
# 209576     Lorna B.  09-09-2021  Walmart
# 209577   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3                invade privacy way much just get grocery
# 4                                           not even deep
# ...                                                   ...
# ...

# %%
# remove the first element in each row
df['Aspect'] = df['Aspect'].apply(lambda x: x[1:])
df
# Out:
#                Name        Time    Store  \
# 0       macantonioc  25-06-2007  DigInfo
# 1       donkeyfly69  27-02-2008  DigInfo
# 2       donkeyfly69  27-02-2008  DigInfo
# 3       donkeyfly69  27-02-2008  DigInfo
# 4       donkeyfly69  27-02-2008  DigInfo
# ...             ...         ...      ...
# 209573      Mark H.  09-09-2020  Walmart
# 209574      Mark H.  09-09-2020  Walmart
# 209575     Lorna B.  09-09-2021  Walmart
# 209576     Lorna B.  09-09-2021  Walmart
# 209577   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3                invade privacy way much just get grocery
# 4                                           not even deep
# ...                                                   ...
# ...

# %%
# drop rows with empty aspect
df = df[df['Aspect'].map(len) > 0]

# %%
df
# Out:
#                    Name        Time    Store  \
# 0           macantonioc  25-06-2007  DigInfo
# 1           donkeyfly69  27-02-2008  DigInfo
# 2           donkeyfly69  27-02-2008  DigInfo
# 3           donkeyfly69  27-02-2008  DigInfo
# 5       upanddownlevel9  13-02-2009  DigInfo
# ...                 ...         ...      ...
# 209571          Eric M.  09-09-2017  Walmart
# 209572          Mark H.  09-09-2020  Walmart
# 209573          Mark H.  09-09-2020  Walmart
# 209576         Lorna B.  09-09-2021  Walmart
# 209577       NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3                invade privacy way much just get grocery
# 5       hmm not just use brain shop hmm hard hmm hmm h...
# ...                                                   ...
# ...

# %%
# save to csv
df.to_csv('Data_full.csv', index=False)

# %%
#convert column time to datetime with format DD-MM-YYYY
df['Time'] = pd.to_datetime(df['Time'], format="%d-%m-%Y")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1044\2751835595.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time'] = pd.to_datetime(df['Time'], format="%d-%m-%Y")

# %%
df
# Out:
#                    Name       Time    Store  \
# 0           macantonioc 2007-06-25  DigInfo
# 1           donkeyfly69 2008-02-27  DigInfo
# 2           donkeyfly69 2008-02-27  DigInfo
# 3           donkeyfly69 2008-02-27  DigInfo
# 5       upanddownlevel9 2009-02-13  DigInfo
# ...                 ...        ...      ...
# 209571          Eric M. 2017-09-09  Walmart
# 209572          Mark H. 2020-09-09  Walmart
# 209573          Mark H. 2020-09-09  Walmart
# 209576         Lorna B. 2021-09-09  Walmart
# 209577       NATISHA J. 2021-09-09  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3                invade privacy way much just get grocery
# 5       hmm not just use brain shop hmm hard hmm hmm h...
# ...                                                   ...
# ...

# %%
#drop rơ before 2018
df = df[df['Time'] >= '2018-01-01']

# %%
df
# Out:
#               Name       Time      Store  \
# 569       Jenae K. 2018-06-01  Amazon Go
# 570       Jenae K. 2018-06-01  Amazon Go
# 571       Jenae K. 2018-06-01  Amazon Go
# 572       Jenae K. 2018-06-01  Amazon Go
# 573       Jenae K. 2018-06-01  Amazon Go
# ...            ...        ...        ...
# 209567  Melissa C. 2020-08-09    Walmart
# 209572     Mark H. 2020-09-09    Walmart
# 209573     Mark H. 2020-09-09    Walmart
# 209576    Lorna B. 2021-09-09    Walmart
# 209577  NATISHA J. 2021-09-09    Walmart
#
#                                                   Comment  \
# 569     store awesome super cool concept definitley se...
# 570     scan app enter store grab whatever want shelf ...
# 571                   product shelf sensor know grab item
# 572                              crazy no cashier no line
# 573     super simple course still worker ensure entran...
# ...                                                   ...
# ...

# %%
#save to csv
df.to_csv('Data_drop_year.csv', index=False)

# %%
# remove rows with walmart as store
df = df[df['Store'] != 'Walmart']

# %%
#save to csv
df.to_csv('Data_drop_walmart.csv', index=False)
