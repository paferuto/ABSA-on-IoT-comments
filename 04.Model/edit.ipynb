# %%
import pandas as pd

# %%
df = pd.read_csv('DataWithLabel.csv')

# %%
df
# Out:
#         Unnamed: 0         Name        Time    Store  \
# 0                0  macantonioc  25-06-2007  DigInfo
# 1                1  donkeyfly69  27-02-2008  DigInfo
# 2                2  donkeyfly69  27-02-2008  DigInfo
# 3                3  donkeyfly69  27-02-2008  DigInfo
# 4                4  donkeyfly69  27-02-2008  DigInfo
# ...            ...          ...         ...      ...
# 209573      223255      Mark H.  09-09-2020  Walmart
# 209574      223256      Mark H.  09-09-2020  Walmart
# 209575      223257     Lorna B.  09-09-2021  Walmart
# 209576      223258     Lorna B.  09-09-2021  Walmart
# 209577      223259   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3                invade privacy way much just get grocery
# 4                                           not even deep
# ...                                                   ...
# 209573     call refund tell would take day get money back
# 209574                                            walmart
# 209575                          improve site much improve
# 209576  far too many grocery available store not avail...
# 209577  place need walmart lead sell good merchandise ...
#
#                                                     label  sentiment_score  \
# 0                             ['', 'shopping experience']           0.4019
# 1                             ['', 'shopping experience']           0.0000
# 2       ['', 'technology', 'general', 'payment and che...           0.0191
# 3                                         ['', 'general']           0.0000
# 4                                                    ['']           0.0000
# ...                                                   ...              ...
# 209573    ['', 'price and value', 'payment and checkout']           0.0000
# 209574                                               ['']           0.0000
# 209575                                               ['']           0.7003
# 209576                      ['', 'technology', 'general']           0.0000
# 209577                        ['', 'shopping experience']           0.7506
#
#         polarity
# 0       positive
# 1        neutral
# 2        neutral
# 3        neutral
# 4        neutral
# ...          ...
# 209573   neutral
# 209574   neutral
# 209575  positive
# 209576   neutral
# 209577  positive
#
# [209578 rows x 8 columns]

# %%
#drop unnecessary columns
df = df.drop(['Unnamed: 0','sentiment_score'], axis=1)
df
# Out:
#                Name        Time    Store  \
# 0       macantonioc  25-06-2007  DigInfo
# 1       donkeyfly69  27-02-2008  DigInfo
# 2       donkeyfly69  27-02-2008  DigInfo
# 3       donkeyfly69  27-02-2008  DigInfo
# 4       donkeyfly69  27-02-2008  DigInfo
# ...             ...         ...      ...
# 209573      Mark H.  09-09-2020  Walmart
# 209574      Mark H.  09-09-2020  Walmart
# 209575     Lorna B.  09-09-2021  Walmart
# 209576     Lorna B.  09-09-2021  Walmart
# 209577   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3                invade privacy way much just get grocery
# 4                                           not even deep
# ...                                                   ...
# 209573     call refund tell would take day get money back
# 209574                                            walmart
# 209575                          improve site much improve
# 209576  far too many grocery available store not avail...
# 209577  place need walmart lead sell good merchandise ...
#
#                                                     label  polarity
# 0                             ['', 'shopping experience']  positive
# 1                             ['', 'shopping experience']   neutral
# 2       ['', 'technology', 'general', 'payment and che...   neutral
# 3                                         ['', 'general']   neutral
# 4                                                    ['']   neutral
# ...                                                   ...       ...
# 209573    ['', 'price and value', 'payment and checkout']   neutral
# 209574                                               ['']   neutral
# 209575                                               ['']  positive
# 209576                      ['', 'technology', 'general']   neutral
# 209577                        ['', 'shopping experience']  positive
#
# [209578 rows x 6 columns]

# %%
#rename label as Aspect
df = df.rename(columns={'label':'Aspect'})
df
# Out:
#                Name        Time    Store  \
# 0       macantonioc  25-06-2007  DigInfo
# 1       donkeyfly69  27-02-2008  DigInfo
# 2       donkeyfly69  27-02-2008  DigInfo
# 3       donkeyfly69  27-02-2008  DigInfo
# 4       donkeyfly69  27-02-2008  DigInfo
# ...             ...         ...      ...
# 209573      Mark H.  09-09-2020  Walmart
# 209574      Mark H.  09-09-2020  Walmart
# 209575     Lorna B.  09-09-2021  Walmart
# 209576     Lorna B.  09-09-2021  Walmart
# 209577   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3                invade privacy way much just get grocery
# 4                                           not even deep
# ...                                                   ...
# 209573     call refund tell would take day get money back
# 209574                                            walmart
# 209575                          improve site much improve
# 209576  far too many grocery available store not avail...
# 209577  place need walmart lead sell good merchandise ...
#
#                                                    Aspect  polarity
# 0                             ['', 'shopping experience']  positive
# 1                             ['', 'shopping experience']   neutral
# 2       ['', 'technology', 'general', 'payment and che...   neutral
# 3                                         ['', 'general']   neutral
# 4                                                    ['']   neutral
# ...                                                   ...       ...
# 209573    ['', 'price and value', 'payment and checkout']   neutral
# 209574                                               ['']   neutral
# 209575                                               ['']  positive
# 209576                      ['', 'technology', 'general']   neutral
# 209577                        ['', 'shopping experience']  positive
#
# [209578 rows x 6 columns]

# %%
# for aspect with multiple words, split them into separate rows
df = df.set_index(df.columns.drop('Aspect',1).tolist()).Aspect.str.split(',', expand=True).stack().reset_index().rename(columns={0:'Aspect'}).loc[:, df.columns]

# %%
# convert aspect to string with alphanumeric characters only
df['Aspect'] = df['Aspect'].str.replace('[^\w\s]','')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9488\3669242881.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Aspect'] = df['Aspect'].str.replace('[^\w\s]','')

# %%
# delete whitespace in aspect
df['Aspect'] = df['Aspect'].str.strip()

# %%
df
# Out:
#                Name        Time    Store  \
# 0       macantonioc  25-06-2007  DigInfo
# 1       macantonioc  25-06-2007  DigInfo
# 2       donkeyfly69  27-02-2008  DigInfo
# 3       donkeyfly69  27-02-2008  DigInfo
# 4       donkeyfly69  27-02-2008  DigInfo
# ...             ...         ...      ...
# 391046     Lorna B.  09-09-2021  Walmart
# 391047     Lorna B.  09-09-2021  Walmart
# 391048     Lorna B.  09-09-2021  Walmart
# 391049   NATISHA J.  09-09-2021  Walmart
# 391050   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                             interesting
# 2                                not even seem convenient
# 3                                not even seem convenient
# 4              not want pay use shopping cart read recipe
# ...                                                   ...
# 391046  far too many grocery available store not avail...
# 391047  far too many grocery available store not avail...
# 391048  far too many grocery available store not avail...
# 391049  place need walmart lead sell good merchandise ...
# 391050  place need walmart lead sell good merchandise ...
#
#                      Aspect  polarity
# 0                            positive
# 1       shopping experience  positive
# 2                             neutral
# 3       shopping experience   neutral
# 4                             neutral
# ...                     ...       ...
# 391046                        neutral
# 391047           technology   neutral
# 391048              general   neutral
# 391049                       positive
# 391050  shopping experience  positive
#
# [391051 rows x 6 columns]

# %%
# drop rows with empty aspect
df2 = df[df['Aspect'] != '']
# count the number of rows
df2.count()
# Out:
# Name        181473
# Time        181473
# Store       181473
# Comment     181473
# Aspect      181473
# polarity    181473
# dtype: int64

# %%
# count unique aspects
df2['Aspect'].nunique()
# Out:
# 10

# %%
#print unique aspects
df2['Aspect'].unique()
# Out:
# array(['shopping experience', 'technology', 'general',
#        'payment and checkout', 'price and value', 'unemployment',
#        'product available and store design', 'privacy and security',
#        'marketing and communication', 'data integration'], dtype=object)

# %%
df2
# Out:
#                Name        Time    Store  \
# 1       macantonioc  25-06-2007  DigInfo
# 3       donkeyfly69  27-02-2008  DigInfo
# 5       donkeyfly69  27-02-2008  DigInfo
# 6       donkeyfly69  27-02-2008  DigInfo
# 7       donkeyfly69  27-02-2008  DigInfo
# ...             ...         ...      ...
# 391042      Mark H.  09-09-2020  Walmart
# 391043      Mark H.  09-09-2020  Walmart
# 391047     Lorna B.  09-09-2021  Walmart
# 391048     Lorna B.  09-09-2021  Walmart
# 391050   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 1                                             interesting
# 3                                not even seem convenient
# 5              not want pay use shopping cart read recipe
# 6              not want pay use shopping cart read recipe
# 7              not want pay use shopping cart read recipe
# ...                                                   ...
# 391042     call refund tell would take day get money back
# 391043     call refund tell would take day get money back
# 391047  far too many grocery available store not avail...
# 391048  far too many grocery available store not avail...
# 391050  place need walmart lead sell good merchandise ...
#
#                       Aspect  polarity
# 1        shopping experience  positive
# 3        shopping experience   neutral
# 5                 technology   neutral
# 6                    general   neutral
# 7       payment and checkout   neutral
# ...                      ...       ...
# 391042       price and value   neutral
# 391043  payment and checkout   neutral
# 391047            technology   neutral
# 391048               general   neutral
# 391050   shopping experience  positive
#
# [181473 rows x 6 columns]

# %%
df2.to_csv('Dataset.csv')
