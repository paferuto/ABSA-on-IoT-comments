# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Dataset.csv')
df
# Out:
#         Unnamed: 0         Name        Time    Store  \
# 0                1  macantonioc  25-06-2007  DigInfo
# 1                3  donkeyfly69  27-02-2008  DigInfo
# 2                5  donkeyfly69  27-02-2008  DigInfo
# 3                6  donkeyfly69  27-02-2008  DigInfo
# 4                7  donkeyfly69  27-02-2008  DigInfo
# ...            ...          ...         ...      ...
# 181468      391042      Mark H.  09-09-2020  Walmart
# 181469      391043      Mark H.  09-09-2020  Walmart
# 181470      391047     Lorna B.  09-09-2021  Walmart
# 181471      391048     Lorna B.  09-09-2021  Walmart
# 181472      391050   NATISHA J.  09-09-2021  Walmart
#
#                                                   Comment  \
# 0                                             interesting
# 1                                not even seem convenient
# 2              not want pay use shopping cart read recipe
# 3              not want pay use shopping cart read recipe
# 4              not want pay use shopping cart read recipe
# ...                                                   ...
# 181468     call refund tell would take day get money back
# 181469     call refund tell would take day get money back
# 181470  far too many grocery available store not avail...
# 181471  far too many grocery available store not avail...
# 181472  place need walmart lead sell good merchandise ...
#
#                       Aspect  polarity
# 0        shopping experience  positive
# 1        shopping experience   neutral
# 2                 technology   neutral
# 3                    general   neutral
# 4       payment and checkout   neutral
# ...                      ...       ...
# 181468       price and value   neutral
# 181469  payment and checkout   neutral
# 181470            technology   neutral
# 181471               general   neutral
# 181472   shopping experience  positive
#
# [181473 rows x 7 columns]

# %%
#drop the column which year is 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017
df=df.drop(df[df['Time'].str[-4:]=='2007'].index)
df=df.drop(df[df['Time'].str[-4:]=='2008'].index)
df=df.drop(df[df['Time'].str[-4:]=='2009'].index)
df=df.drop(df[df['Time'].str[-4:]=='2010'].index)
df=df.drop(df[df['Time'].str[-4:]=='2011'].index)
df=df.drop(df[df['Time'].str[-4:]=='2012'].index)
df=df.drop(df[df['Time'].str[-4:]=='2013'].index)
df=df.drop(df[df['Time'].str[-4:]=='2014'].index)
df=df.drop(df[df['Time'].str[-4:]=='2015'].index)
df=df.drop(df[df['Time'].str[-4:]=='2016'].index)
df=df.drop(df[df['Time'].str[-4:]=='2017'].index)
df
# Out:
#         Unnamed: 0        Name        Time      Store  \
# 558           1128    Jenae K.  01-06-2018  Amazon Go
# 559           1129    Jenae K.  01-06-2018  Amazon Go
# 560           1131    Jenae K.  01-06-2018  Amazon Go
# 561           1132    Jenae K.  01-06-2018  Amazon Go
# 562           1134    Jenae K.  01-06-2018  Amazon Go
# ...            ...         ...         ...        ...
# 181468      391042     Mark H.  09-09-2020    Walmart
# 181469      391043     Mark H.  09-09-2020    Walmart
# 181470      391047    Lorna B.  09-09-2021    Walmart
# 181471      391048    Lorna B.  09-09-2021    Walmart
# 181472      391050  NATISHA J.  09-09-2021    Walmart
#
#                                                   Comment  \
# 558     store awesome super cool concept definitley se...
# 559     store awesome super cool concept definitley se...
# 560     scan app enter store grab whatever want shelf ...
# 561     scan app enter store grab whatever want shelf ...
# 562                   product shelf sensor know grab item
# ...                                                   ...
# 181468     call refund tell would take day get money back
# 181469     call refund tell would take day get money back
# 181470  far too many grocery available store not avail...
# 181471  far too many grocery available store not avail...
# 181472  place need walmart lead sell good merchandise ...
#
#                              Aspect  polarity
# 558                data integration  positive
# 559     marketing and communication  positive
# 560                      technology  positive
# 561            payment and checkout  positive
# 562                      technology   neutral
# ...                             ...       ...
# 181468              price and value   neutral
# 181469         payment and checkout   neutral
# 181470                   technology   neutral
# 181471                      general   neutral
# 181472          shopping experience  positive
#
# [131164 rows x 7 columns]

# %%
#export to csv
df.to_csv('Dataset_DropYear.csv', index=False)

# %%
#drop comment with Store Walmart
df1=df.drop(df[df['Store']=='Walmart'].index)
df1
# Out:
#         Unnamed: 0      Name        Time      Store  \
# 558           1128  Jenae K.  01-06-2018  Amazon Go
# 559           1129  Jenae K.  01-06-2018  Amazon Go
# 560           1131  Jenae K.  01-06-2018  Amazon Go
# 561           1132  Jenae K.  01-06-2018  Amazon Go
# 562           1134  Jenae K.  01-06-2018  Amazon Go
# ...            ...       ...         ...        ...
# 181237      390586     AJ M.  09-04-2022     Kroger
# 181238      390588     AJ M.  09-04-2022     Kroger
# 181239      390589     AJ M.  09-04-2022     Kroger
# 181240      390593     AJ M.  09-04-2022     Kroger
# 181241      390594     AJ M.  09-04-2022     Kroger
#
#                                                   Comment  \
# 558     store awesome super cool concept definitley se...
# 559     store awesome super cool concept definitley se...
# 560     scan app enter store grab whatever want shelf ...
# 561     scan app enter store grab whatever want shelf ...
# 562                   product shelf sensor know grab item
# ...                                                   ...
# 181237                               shelf not well stock
# 181238  literally nag sign one card not need card pric...
# 181239  literally nag sign one card not need card pric...
# 181240  use fine place many year great management help...
# 181241  use fine place many year great management help...
#
#                              Aspect  polarity
# 558                data integration  positive
# 559     marketing and communication  positive
# 560                      technology  positive
# 561            payment and checkout  positive
# 562                      technology   neutral
# ...                             ...       ...
# 181237                   technology  negative
# 181238                   technology  positive
# 181239                 unemployment  positive
# 181240          shopping experience  positive
# 181241                 unemployment  positive
#
# [72339 rows x 7 columns]

# %%
#export to csv
df1.to_csv('Dataset_DropWalmart.csv', index=False)
